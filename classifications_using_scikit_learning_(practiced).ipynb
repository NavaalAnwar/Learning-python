# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams["figure.figsize"] = [10,5]
# Ignore warnings

import warnings
# Set the warning filter to ignore FutureWarning
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
current_palette1 = sns.color_palette()

sns.palplot(current_palette1)

plt.show()

# %%
current_palette2 = sns.color_palette()

sns.palplot( sns.color_palette("Blues"))

plt.show()

# %%
current_palette3 = sns.color_palette()

sns.palplot(sns.color_palette("BrBG", 7))

plt.show()

# %%
current_palette4 = sns.color_palette()
sns.palplot(sns.color_palette("colorblind"))
plt.show()

# %% [markdown]
# #Seaborn on Titanic dataset

# %%
full_data = pd.read_csv('/titanic_dataset.csv')

# %% [markdown]
# **Checking rows, columns **

# %%
full_data.shape
# Out:
# (891, 12)

# %% [markdown]
# **Representation of Whole Data**

# %%
full_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **Printing Data info**

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #Printing Rows & Columns separately

# %% [markdown]
# **Printing Columns**

# %%
full_data['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
full_data['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# **Printing Row**

# %%
df= pd.DataFrame(full_data)
print(df.iloc[3])
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                    35.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
df = pd.DataFrame(full_data)
print(df.loc[1])
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %% [markdown]
# #Plots

# %% [markdown]
# **Printing Whole data Graph**

# %%
sns.histplot(full_data)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# #1.Distribution Plot

# %% [markdown]
# **Displot**

# %% [markdown]
# this plots graph using histogram

# %%
sns
# Out:
# <module 'seaborn' from '/usr/local/lib/python3.10/dist-packages/seaborn/__init__.py'>

# %%
sns.histplot(full_data['Pclass'], kde=False)
plt.show()

# %% [markdown]
# **KDE Plot** **(Kernal Density Estimation)**

# %% [markdown]
# In this a graph is ploted using a line. delcaring hist=false means that the graph will be plotted only using line not bars

# %%
sns.distplot(full_data['Parch'], hist=False)
plt.show()

# %%
sns.distplot(full_data['Pclass'])
plt.show()

# %% [markdown]
# This is the graph in which we donot specify the type of graph that it should represent the data in bar form or line

# %% [markdown]
# #Relational plots

# %% [markdown]
# There three subplots of Relational plot
#
# * Relplot
# * Scatter Plot
# * Line Plot

# %% [markdown]
# **Relplot**

# %% [markdown]
# In this we can create a graph with line or dots just by delcaring type of kind whether it is line plot of scatter

# %%
plt.figure(figsize=(8,8))
sns.relplot(x="Ticket", y="Fare",hue="Sex", style="Sex",kind="scatter", data=full_data) # scatter can be used instead of "line" plot
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
full_data = pd.read_csv('/titanic_dataset.csv')

# %%
plt.figure(figsize=(8,8))
sns.barplot(x="Sex", y="Survived", hue="Pclass", data=full_data)
plt.show()

# %% [markdown]
# **Line Plot**

# %%
plt.figure(figsize=(8,8))
sns.lineplot(x="Age", y="Fare", hue="Sex", style="Sex", data=full_data)
plt.show()

# %% [markdown]
# **Scatter plot**

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x="Pclass", y="Age", data=full_data)
plt.show()

# %% [markdown]
# #Categorical Plot

# %% [markdown]
# There further 7 subclasses of categorical Plot
#
# *   Bar Plot
# *   Strip Plot
# *   Swarm Plot
# *   Box Plot
# *   Violin Plot
# *   Count Plot
# *   Point Plot

# %% [markdown]
# **Bar Plot**

# %%
plt.figure(figsize=(7,7))
sns.barplot(x = "Sex", y= "Age", hue="Sex", data=full_data)
plt.show()

# %% [markdown]
# **Strip Plot**

# %%
plt.figure(figsize=(8,8))
sns.stripplot(x='Embarked',y='Sex', hue="Sex", data=full_data)
plt.show()

# %% [markdown]
# **Swarm Plot**

# %%
plt.figure(figsize=(8,8))
sns.swarmplot(x="Age", y="Sex", hue='Sex', data=full_data)
plt.show()

# %% [markdown]
# **Box Plot**

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x="Sex", y="Survived", data=full_data)
plt.show()

# %% [markdown]
# **Violin Plot**

# %%
plt.figure(figsize=(8,8))
sns.violinplot(x="Survived", y="Age", hue="Sex", data=full_data)
plt.show()

# %% [markdown]
# **Count Plot**

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="Pclass",hue="Pclass", data=full_data )
plt.show()

# %% [markdown]
# **Point Plot**

# %%
plt.figure(figsize=(8,8))
sns.pointplot(x="Survived", y="Sex", hue="Pclass", data=full_data)
plt.show()

# %% [markdown]
# #Regression Plot

# %% [markdown]
# This plot is used to better visualize the relationship between two variables and to check how well the model fits the data

# %% [markdown]
# **Lmplot**

# %%
sns.lmplot(x="Fare", y="Age", data=full_data)
plt.show()

# %% [markdown]
# #Matrix plot

# %% [markdown]
# **Heatmap**

# %% [markdown]
# This plot is used for better visualizing of many variables using heatmap. In this vclosely relatede variables are assinged the same color and plot a graph using seaborn library

# %%
full_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df= pd.DataFrame(full_data)

# %%
df= df.drop('Name', axis=1)
print(df)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
print(full_data.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
full_data = full_data.drop('Name', axis=1)

# %% [markdown]
# **Printing data of columns**

# %%
print(full_data.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
full_data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# **Removing String Columns**

# %%
full_data= full_data.drop('Sex', axis=1)

# %%
full_data= full_data.drop('Ticket', axis=1)

# %%
full_data= full_data.drop('Embarked', axis=1)

# %%
full_data
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
sns.heatmap(full_data.corr(),  cmap="coolwarm", annot=True, fmt=".2f")
plt.show()

# %% [markdown]
# **finding missing data in our table **

# %%
missing_data=df.isna().sum()
print(missing_data)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# **Looking for missing data of a particular column**

# %%
missing_in_column = df['Cabin'].isna()  # or df['A'].isnull()
print(missing_in_column)
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %% [markdown]
# #MultiPlot Grids

# %% [markdown]
# **Facet grids**

# %% [markdown]
# In this facet grid creates multiple plots in one grid to compare the categories and subsets

# %%
g= sns.FacetGrid(full_data, col="Survived", row='Pclass')
g.map(plt.hist, "Age")
g.add_legend()

# %%
g.add_legend()

# %% [markdown]
# #TRAINING DATA PRE-PROCESSING

# %% [markdown]
# This is a pre-processing used for preparing a raw data for training a machine learning model. Because well organized data help machine to learn better and more  perform more accurately. The task involved in this are:
#
#
# *   Cleaning Data
# *   Transforming data
# *   Featuring data
# *   Splitting Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams["figure.figsize"] = [10,5]
# Ignore warnings

import warnings
# Set the warning filter to ignore FutureWarning
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
full_data = pd.read_csv('/titanic_dataset.csv')

# %%
def impute_age(cols):
    Age = cols[0]
    Pclass = cols[1]

    if pd.isnull(Age):

        if Pclass == 1:
            return 37

        elif Pclass == 2:

            return 29

        else:
            return 24

    else:
        return Age

full_data['Age']=full_data[['Age','Pclass']].apply(impute_age, axis =1 )

# %%
full_data=pd.DataFrame(full_data)

# %%
missing_data=df.isna()

# %%
print(missing_data)
# Out:
#      PassengerId  Survived  Pclass    Sex    Age  SibSp  Parch  Ticket   Fare  \
# 0          False     False   False  False  False  False  False   False  False
# 1          False     False   False  False  False  False  False   False  False
# 2          False     False   False  False  False  False  False   False  False
# 3          False     False   False  False  False  False  False   False  False
# 4          False     False   False  False  False  False  False   False  False
# ..           ...       ...     ...    ...    ...    ...    ...     ...    ...
# 886        False     False   False  False  False  False  False   False  False
# 887        False     False   False  False  False  False  False   False  False
# 888        False     False   False  False   True  False  False   False  False
# 889        False     False   False  False  False  False  False   False  False
# 890        False     False   False  False  False  False  False   False  False
#
#      Cabin  Embarked
# ...

# %% [markdown]
# here, we have a column cabin that have missing values  so we can remove cabin column from the table because it is not providing any usefull information

# %%
full_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
full_data= full_data.drop('Cabin', axis=1)

# %%
full_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Here we have Name and Ticket are extra column they donot play any informative role in predicting the survival rate of patients so we remove these two columns

# %%
full_data=full_data.drop('Name', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-247-bd3e2481d60f> in <cell line: 1>()
# ----> 1 full_data=full_data.drop('Name', axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# -> 4711                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4712
#    4713         if inplace:
#
# ...

# %%
full_data=full_data.drop('Ticket', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-248-12068bdfb9ec> in <cell line: 1>()
# ----> 1 full_data=full_data.drop('Ticket', axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# -> 4711                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4712
#    4713         if inplace:
#
# ...

# %% [markdown]
# Here we remove the Name and Ticket columns using the above line of code

# %%
full_data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  24.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked   male  ...      Q      S  female   male      C      Q      S  \
# ...

# %% [markdown]
# Now we are converting 2 objects to category data type

# %%
objcat=['Sex','Age']

# %%
for colname in objcat:
  full_data[colname]=full_data[colname].astype('category')

# %%
full_data.shape
# Out:
# (891, 9)

# %%
full_data.select_dtypes(['category']).columns
# Out:
# Index(['Sex', 'Age'], dtype='object')

# %% [markdown]
# **This is the numeric representation of data**

# %%
full_data.describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000    8.000000    6.000000  512.329200

# %%
full_data = pd.read_csv('/titanic_dataset.csv')
sex = pd.get_dummies(full_data['Sex'], drop_first=False)
embarked = pd.get_dummies(full_data['Embarked'], drop_first=False)

x= pd.concat([full_data[['Sex', 'Embarked']], sex],axis=1)

# %%
full_data = pd.concat([full_data, sex, embarked], axis = 1)
full_data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  female   male      C  \
# 0      0         A/5 21171   7.2500   NaN        S   False   True  False
# 1      0          PC 17599  71.2833   C85        C    True  False   True
# 2      0  STON/O2. 3101282   7.9250   NaN        S    True  False  False
# ...

# %% [markdown]
# #Target Splitting Variable

# %%
x = full_data.drop('Survived', axis = 1)
y = full_data['Survived']

# %%
x.shape
# Out:
# (891, 42)

# %%
y.shape
# Out:
# (891,)
